# %% [markdown]
# # Bài Tập

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ### Bài 1: Tạo quần thể mô phỏng
#
# Bạn hãy tạo một mẫu gồm 10000 phần tử mô phỏng chiều cao của nam thanh niên có giá trị từ 120cm - 200cm. Bạn hãy lưu kết quả vào biến **POP**.
#
# Tính:
# a. Chiều cao trung bình (kỳ vọng) của quần thể và độ lệch chuẩn về chiều cao của quần thể.
#
# b. Tính tỷ lệ người cao trong quần thể, biết rằng thanh niên có chiều cao từ 180 trở lên được gọi là cao.
#
# c. Vẽ histogram về chiều cao của quần thể. Theo bạn quần thể có phân phối chuẩn hay không?
#
# d. Thử vẽ histogram và đồ thị hàm mật độ của phân phối chuẩn sử dụng tham số loc và scale bằng với kỳ vọng và độ lệch chuẩn của quần thể.

# %%
# Tạo population
height_pop_10k = np.random.randint(120, 200, 10000)

# %%
# a. Chiều cao trung bình (kỳ vọng) của quần thể và độ lệch chuẩn về chiều cao của quần thể.
height_mean = np.mean(height_pop_10k)
height_std = np.std(height_pop_10k)

print(f'Chiều cao trung bình của quần thể: {round(height_mean, 4)}')

print(f'Độ lệch chuẩn về chiều cao của quần thể: {round(height_std, 4)}')
# Out:
# Chiều cao trung bình của quần thể: 159.4785
# Độ lệch chuẩn về chiều cao của quần thể: 22.9964

# %%
# b. Tính tỷ lệ người cao trong quần thể, biết rằng thanh niên có chiều cao từ 180 trở lên được gọi là cao.
tall_people_rate = len(height_pop_10k[height_pop_10k >= 180]) / len(height_pop_10k)

print("Tỷ lệ người cao trong quần thể: ", round(tall_people_rate, 4))
# Out:
# Tỷ lệ người cao trong quần thể:  0.2461

# %%
# c. Vẽ histogram về chiều cao của quần thể. Theo bạn quần thể có phân phối chuẩn hay không?
sns.histplot(height_pop_10k, kde=True)
print("Quần thể không phân phối chuẩn")
# Out:
# Quần thể không phân phối chuẩn

# %%
# d. Thử vẽ histogram và đồ thị hàm mật độ của phân phối chuẩn
# sử dụng tham số loc và scale bằng với kỳ vọng và độ lệch chuẩn của quần thể.
plt.hist(height_pop_10k, bins=30, alpha=0.6, density=True)

x = np.linspace(height_pop_10k.min(), height_pop_10k.max(), 100)
y = stats.norm.pdf(x, loc=height_mean, scale=height_std)
plt.plot(x, y)

plt.show()

# %% [markdown]
# ### Bài 2: Lấy mẫu cỡ 20
#
# Bạn hãy lấy một mẫu kích thước 20 phần từ. Tính:
#
# a. Trung bình mẫu, và độ lệch chuẩn của mẫu
#
# b. Tỷ lệ người cao của mẫu
#
# c. Vẽ histogram của mẫu
#
# d. Thử vẽ đồ thị hàm mật độ của phân phối chuẩn với tham số loc và scale bằng với giá trị trung bình và độ lệch chuẩn và chiều cao của mẫu. Bạn có nhận xét gì không?

# %%
# Tạo sample
height_sample_20 = np.random.choice(height_pop_10k, 20)

# %%
# a) Trung bình, độ lệch chuẩn
height_sample_mean = np.mean(height_sample_20)
height_sample_std = np.std(height_sample_20)

print(f'Chiều cao trung bình của sample: {round(height_sample_mean, 4)}')
print(f'Độ lệch chuẩn về chiều cao của sample: {round(height_sample_std, 4)}')
# Out:
# Chiều cao trung bình của sample: 161.8
# Độ lệch chuẩn về chiều cao của sample: 19.8257

# %%
# b) Tỷ lệ người cao trong sample
tall_people_rate_sample = len(height_sample_20[height_sample_20 >= 180]) / len(height_sample_20)

print("Tỷ lệ người cao trong sample: ", round(tall_people_rate_sample, 4))
# Out:
# Tỷ lệ người cao trong sample:  0.2

# %%
# c) Vẽ histogram của mẫu
sns.histplot(height_sample_20, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# d) Thử vẽ histogram và đồ thị hàm mật độ của phân phối chuẩn và nhận xét
plt.hist(height_sample_20, bins=30, alpha=0.6, density=True)

x = np.linspace(height_sample_20.min(), height_sample_20.max(), 100)
y = stats.norm.pdf(x, loc=height_sample_mean, scale=height_sample_std)
plt.plot(x, y)

plt.show()

# %% [markdown]
# ### Bài 3: Lấy mẫu cỡ 100
#
# Lặp lại thí nghiệm bài 2 với cỡ mẫu là 100

# %%
# Tạo sample 100
height_sample_100 = np.random.choice(height_pop_10k, 100)

# %%
# a) Trung bình, độ lệch chuẩn
height_sample_mean_100 = np.mean(height_sample_100)
height_sample_std_100 = np.std(height_sample_100)

print(f'Chiều cao trung bình của sample: {round(height_sample_mean_100, 4)}')
print(f'Độ lệch chuẩn về chiều cao của sample: {round(height_sample_std_100, 4)}')
# Out:
# Chiều cao trung bình của sample: 159.91
# Độ lệch chuẩn về chiều cao của sample: 22.2311

# %%
# b) Tỷ lệ người cao trong sample
tall_people_rate_sample_100 = len(height_sample_100[height_sample_100 >= 180]) / len(height_sample_100)

print("Tỷ lệ người cao trong sample: ", round(tall_people_rate_sample_100, 4))
# Out:
# Tỷ lệ người cao trong sample:  0.28

# %%
# c) Vẽ histogram của mẫu
sns.histplot(height_sample_100, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# d) Thử vẽ histogram và đồ thị hàm mật độ của phân phối chuẩn và nhận xét
plt.hist(height_sample_100, bins=30, alpha=0.6, density=True)

x = np.linspace(height_sample_100.min(), height_sample_100.max(), 100)
y = stats.norm.pdf(x, loc=height_sample_mean_100, scale=height_sample_std_100)
plt.plot(x, y)

plt.show()

# %% [markdown]
# ### Bài 4: Khảo sát phân phối của trung bình mẫu
#
# a. Thực hiện bài 2 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# b. Thực hiện bài 3 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# c. Vẽ histogram của hai câu a, b trong cùng một hình để so sánh. Theo bạn hình dạng của histogram thay đổi nói lên điều gì?
#
# Gợi ý: tạo một danh sách rỗng để chứa các trung bình mẫu tính được, sử dụng hàm append() để thêm giá trị trung bình vào danh sách sau mỗi lần tính.

# %%
# a. Thực hiện bài 2 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
means = []

for i in range(100):
    sample = np.random.choice(height_pop_10k, 20)
    means.append(np.mean(sample))
    
sns.histplot(means, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# b. Thực hiện bài 3 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
means_100 = []

for i in range(100):
    sample = np.random.choice(height_pop_10k, 100)
    means_100.append(np.mean(sample))
    
sns.histplot(means_100, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# c. Vẽ histogram của hai câu a, b trong cùng một hình để so sánh. Theo bạn hình dạng của histogram thay đổi nói lên điều gì?
plt.hist(means, bins=30, alpha=0.6, density=True)
plt.hist(means_100, bins=30, alpha=0.6, density=True)

plt.show()
# Out:
# (array([0.02583979, 0.02583979, 0.02583979, 0.        , 0.        ,
#         0.07751938, 0.07751938, 0.12919897, 0.07751938, 0.18087855,
#         0.12919897, 0.18087855, 0.15503876, 0.12919897, 0.18087855,
#         0.12919897, 0.07751938, 0.10335917, 0.10335917, 0.18087855,
#         0.10335917, 0.12919897, 0.12919897, 0.05167959, 0.07751938,
#         0.07751938, 0.        , 0.        , 0.        , 0.02583979]),
#  array([153.86 , 154.247, 154.634, 155.021, 155.408, 155.795, 156.182,
#         156.569, 156.956, 157.343, 157.73 , 158.117, 158.504, 158.891,
#         159.278, 159.665, 160.052, 160.439, 160.826, 161.213, 161.6  ,
#         161.987, 162.374, 162.761, 163.148, 163.535, 163.922, 164.309,
#         164.696, 165.083, 165.47 ]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ### Bài 5: Khảo sát tỷ lệ mẫu
#
# a. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram tỷ lệ người cao của các mẫu
#
# b. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 500. Vẽ histogram tỷ lệ người cao của các mẫu

# %%
# a. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram tỷ lệ người cao của các mẫu
tall_people_rates = []

for i in range(1000):
    sample = np.random.choice(height_pop_10k, 100)
    tall_people_rates.append(len(sample[sample >= 180]) / len(sample))
    
sns.histplot(tall_people_rates, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# b. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 500. Vẽ histogram tỷ lệ người cao của các mẫu
tall_people_rates_500 = []

for i in range(1000):
    sample = np.random.choice(height_pop_10k, 500)
    tall_people_rates_500.append(len(sample[sample >= 180]) / len(sample))
    
sns.histplot(tall_people_rates_500, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ### Bài 6: Khảo sát phương sai mẫu
#
# Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram đại lượng phương sai của các mẫu (Phương sai bằng bình phương độ lệch chuẩn)

# %%
variances_100 = []

for i in range(1000):
    sample = np.random.choice(height_pop_10k, 100)
    variances_100.append(np.var(sample))

sns.histplot(variances_100, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ### Bài 7:  Bài Tập Ước Lượng
#
# Khảo sát cân nặng (kg) của gà khi xuất chuồng, người ta cân một số con và có kết quả như sau:
#
# > 2.1, 1.8, 2.0, 2.3, 1.7, 1.5, 2.0, 2.2, 1.8
#
# Giả sử cân nặng của gà là biến ngẫu nhiên có phân phối chuẩn. Hãy lập khoảng tin cậy cho cân nặng trung bình của  khi xuất chuồng với độ tin cậy là 95%. Trong 2 trường hợp:
#
# a, Biết $\sigma = 0.3$
#
# b, Không biết $\sigma$

# %%
# Giả sử cân nặng của gà là biến ngẫu nhiên có phân phối chuẩn. Hãy lập khoảng tin cậy cho cân nặng trung bình của 
# khi xuất chuồng với độ tin cậy là 95%. Trong 2 trường hợp:
# a. sigma = 0.3
weight_pop = [2.1, 1.8, 2.0, 2.3, 1.7, 1.5, 2.0, 2.2, 1.8]
sigma = 0.3
alpha = 0.05

weight_mean = np.mean(weight_pop)
n = len(weight_pop) 
z = stats.norm.ppf(1 - alpha/2)

ci = [round(weight_mean - z * sigma / np.sqrt(n), 4), round(weight_mean + z * sigma / np.sqrt(n), 4)]

print(f'Khoảng tin cậy cho cân nặng trung bình của khi xuất chuồng với độ tin cậy 95% (sigma = 0.3): {ci}')
# Out:
# Khoảng tin cậy cho cân nặng trung bình của khi xuất chuồng với độ tin cậy 95% (sigma = 0.3): [1.7373, 2.1293]

# %%
# b. Không biết sigma
weight_mean = np.mean(weight_pop)
n = len(weight_pop)
alpha = 0.05
t = stats.t.ppf(1 - alpha/2, n - 1)
s = np.std(weight_pop, ddof=1)
ci = [round(weight_mean - t * s / np.sqrt(n), 4), round(weight_mean + t * s / np.sqrt(n), 4)]

print(f'Khoảng tin cậy cho cân nặng trung bình của khi xuất chuồng với độ tin cậy 95% (không biết sigma): {ci}')
# Out:
# Khoảng tin cậy cho cân nặng trung bình của khi xuất chuồng với độ tin cậy 95% (không biết sigma): [1.7374, 2.1293]
