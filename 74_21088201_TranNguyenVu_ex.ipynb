# %% [markdown]
# # Lab 03 - Bài tập

# %% [markdown]
# ## NUMPY
#
# Bạn hãy phát sinh ngẫu nhiên mảng ndarray có tên `arr` gồm 100 phần tử số nguyên có giá trị từ 0..1000. Thực hiện các thao tác sau:

# %%
import numpy as np
from numpy import random

arr = random.randint(1000, size=(100))

print(arr)
# Out:
# [173 464 987 273 726 545 185 924 976 610 930 769 192 680 714 697 337 255
#  153 194 328 719 121   6 888 788 271 731 545 640 354 676 909 186 748 150
#  902 770 421 773 429 131 178 786 608 632 603 177 195 565 996 884  27 136
#  779 166 409 782 173 138 722 369 862 756 638 956 430 930 341 853 385 152
#  655 913 870 228 858 672 473 437  76 704 607 317 850 447 933 837 731 996
#  559 184  72 939 899 608 174  81 572  76]

# %% [markdown]
# ### 1. Hiển thị các phần tử thỏa yêu cầu dưới đây
#
# - 10 phần tử đầu tiên
# - 5 phần tử cuối cùng
# - Các phần tử thỏa mãn điều kiện chia hết cho 5 và lớn hơn 100

# %%
print("First 10 elements: ", arr[:10])
print("Last 5 elements", arr[-5:])
# Out:
# First 10 elements:  [173 464 987 273 726 545 185 924 976 610]
# Last 5 elements [608 174  81 572  76]

# %% [markdown]
# ### 2. Cho biết mảng trên có bao nhiêu phần tử có giá trị nhỏ hơn 100. Hiển thị các phần tử đó

# %%
elements_smaller_than_100 = arr[arr < 100]

print("Elements smaller than 100: ", elements_smaller_than_100)
print("Number of elements: ", len(elements_smaller_than_100))
# Out:
# Elements smaller than 100:  [ 6 27 76 72 81 76]
# Number of elements:  6

# %% [markdown]
# ### 3. Thực hiện thống kê:
#
# - Tính tổng mảng
# - Tìm giá trị trung bình
# - Tìm giá trị trung vị
# - Tìm Q1, Q2, Q3
# - Tìm phân vị 20 (percentile 20)

# %%
print("Sum:", np.sum(arr))
print("Mean:", np.mean(arr))
print("Median:", np.median(arr))
print("Q1:", np.percentile(arr, 25))
print("Q2: (Median)", np.percentile(arr, 50))
print("Q3:", np.percentile(arr, 75))
print("Percentile 20:", np.percentile(arr, 20))
# Out:
# Sum: 53666
# Mean: 536.66
# Median: 605.0
# Q1: 219.75
# Q2: (Median) 605.0
# Q3: 779.75
# Percentile 20: 184.8

# %% [markdown]
# ### 4. Thực hiện việc chọn ngẫu nhiên (không thay thế) 10 phần tử từ mảng trên 5 lần. Hiển thị kết quả lựa chọn mỗi lần

# %%
for i in range(5):
    print(random.choice(arr, 10))
# Out:
# [150 150 607 228  72 697 464 464   6 565]
# [756 976 195 328 430 255 655 177 930 131]
# [ 76 545 131 837 933 697 731 779 638 779]
# [858 430 273 192 632 731 748 933 195   6]
# [884 788 610 385 429 194 996 271 731 640]

# %% [markdown]
# ### 5. Tìm phần tử xuất hiện nhiều nhất trong mảng

# %%
print("Most frequent element:", np.bincount(arr).argmax())
# Out:
# Most frequent element: 76

# %% [markdown]
# ---

# %% [markdown]
# ## MATPLOTLIB

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Viết mã để vẽ các đồ thị sau:

# %% [markdown]
# ### Câu 1: Đồ thị đường thẳng

# %%
# Your code here
plt.plot([1, 2, 3], [2, 4, 1])
plt.show()

# %% [markdown]
# ### Câu 2: Vẽ hai đường thẳng

# %%
# Your code here
plt.plot([10, 20, 30], [40, 10, 30], color="blue", label = 'line 1')
plt.plot([10, 20, 30], [20, 40, 10], color="red", label = 'line 2')
plt.title("Do thi 2 duong thang")
plt.xlabel("x - axis")
plt.ylabel("y - axis")
plt.legend()
plt.show()

# %% [markdown]
# ### Câu 3: Sử dụng marker

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot([1, 4, 5, 6, 7], [2, 6, 3, 6, 3], marker='o', mfc='orange')
plt.title("Su dung marker")
plt.xlabel("x - axis")
plt.ylabel("y - axis")
plt.show()

# %%
# Your code here

# %% [markdown]
# ### Câu 4: Định dạng đường thẳng
#
# Phát sinh x là các điểm dữ liệu từ $[0, \pi]$. Bạn hãy vẽ đồ thị $y = sin(x)$ và $y = cos(x)$ như dưới đây.
# Gợi ý: sử dụng hằng số pi và hàm sau:
# - `np.pi` : số $\pi$
# - `np.linspace()`
# - `np.sin()`
# - `np.cos()`

# %%
# Your code here
x = np.linspace(0, 6, 100)
sinx = np.sin(x)
cosx = np.cos(x)

plt.plot(x, sinx, label="sin(x)")
plt.plot(x, cosx, label="cos(x)", ls="--")
plt.title("Do thi sin(x) va cos(x)")
plt.xlabel("x - axis")
plt.ylabel("y - axis")
plt.legend()
plt.show()

# %% [markdown]
# ### Câu 5: Vẽ các đồ thị con

# %%
# Your code here
x = np.linspace(0, 6, 100)
sinx = np.sin(x)
cosx = np.cos(x)

plt.subplot(2, 1, 1)
plt.plot(x, sinx, label="sin(x)")
plt.title("Do thi sin(x) va cos(x)")
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(x, cosx, label="cos(x)", color='red')
plt.legend()

plt.show()

# %% [markdown]
# ### Câu 6: Vẽ đồ thị cột

# %%
# Your code here
x = np.array(['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'])
y = np.array([22, 18, 9, 8, 7, 6])

plt.bar(x, y)
plt.title("Muc do pho bien cua cac ngon ngu lap trinh")
plt.xlabel("Programming Language")
plt.ylabel("Popularity")
plt.show()

# %% [markdown]
# ### Câu  7: Vẽ đồ thị bánh

# %%
y = np.array([31.27, 24.79, 12.39, 11.27, 10.85, 9.44])
my_labels = np.array(['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'])
explode = (0.1, 0, 0, 0, 0, 0)

plt.pie(y, labels=my_labels, autopct='%1.2f%%', shadow = True, explode=explode, startangle=-90)
plt.show()

# %%
# Your code here

# %% [markdown]
# ### Câu 8: Vẽ histogram
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ histogram các số ngẫu nhiên trên.

# %%
# Your code here
random_10k = np.random.normal(size=10000)

plt.hist(random_10k, bins=100)
plt.title("Histogram")
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Câu 9: Vẽ đồ thị hộp
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ boxplot các số ngẫu nhiên trên.

# %%
# Your code here
plt.boxplot(x=random_10k)
plt.title('Boxplot')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Câu 10: Kết hợp trên cùng một đồ thị
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ hình thể hiện phân phối như sau:
#
# Hướng dẫn: thêm tham số `vert=False` trong hàm vẽ `boxplot()`

# %%
# Your code here
plt.subplot(2, 1, 1)
plt.hist(random_10k, bins=100, edgecolor='white')
plt.title("Histogram")
plt.ylabel("Mat do")

plt.subplot(2, 1, 2)
plt.boxplot(x=random_10k, vert=False)
plt.title("Boxplot")
plt.suptitle("Do thi sin(x) va cos(x)")

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## SEABORN

# %% [markdown]
# Seaborn là một thư viện hỗ trợ trực quan hóa được viết dựa trên thư viện `matplotlib`. Trong bài tập này, bạn hãy tự tìm hiểu thư viện `seaborn` và trực quan hóa dữ liệu tiền tip tại một nhà hàng.
#
# Bạn có thể dùng đoạn mã sau để đọc dữ liệu có sẵn trong `seaborn`
#
# ```python
# import seaborn as sns
#
# df = sns.load_dataset("tips")
# df.head()
# ```
# Hoặc bạn có thể đọc dữ liệu chứa trong file `tips.csv` chứa thông tin tiền tip của khách hàng tại một nhà hàng. Dữ liệu có các thông tin sau:
#
# - `total_bill`: tổng hoá đơn (USD)
# - `tip`: tiền tip/ tiền boa (USD)
# - `sex`: giới tính người thanh toán hóa đơn
# - `smoker`: có hút thuốc hay không
# - `day`: ngày trong tuần
# - `time`: thời gian dùng bữa(buổi sáng, buổi trưa, buổi tối)
# - `size`: số lượng người tham gia
#
# Bạn hãy lựa chọn loại đồ thị phù hợp để trả lời những câu hỏi sau:

# %%
# Import seaborn
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset("tips")
print(df.head())
print(df.info())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %% [markdown]
# ### 1. Vẽ đồ thị thể hiện tổng tiền tip theo ngày

# %%
tips_by_day = df.groupby('day').sum()['tip']

sns.barplot(x=tips_by_day.index, y=tips_by_day.values)
# Out:
# /tmp/ipykernel_9371/2498627137.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tips_by_day = df.groupby('day').sum()['tip']
# <Axes: xlabel='day'>

# %% [markdown]
# ### 2. Vẽ đồ thị thể hiện tổng tiền tip theo thời gian dùng bữa (time)

# %%
tips_by_time = df.groupby('time').sum()['tip']

sns.barplot(x=tips_by_time.index, y=tips_by_time.values)
# Out:
# /tmp/ipykernel_9371/258964846.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tips_by_time = df.groupby('time').sum()['tip']
# <Axes: xlabel='time'>

# %% [markdown]
# ### 3. Vẽ đồ thị histogram của tổng hoá đơn

# %%
sns.histplot(df['total_bill'], bins=100)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### 4. Vẽ đồ thị boxplot của tổng hoá đơn

# %%
sns.boxplot(x=df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# ### 5. Vẽ đồ thị boxplot so sánh tổng hóa đơn giữa các ngày trong tuần

# %%
total_bill_by_day = df.groupby('day').sum()['total_bill']

sns.boxplot(x=df['day'], y=df['total_bill'])
# Out:
# /tmp/ipykernel_9371/2129843684.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_bill_by_day = df.groupby('day').sum()['total_bill']
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### 6. Vẽ đồ thị để kiểm tra sự liên quan giữa tổng hoá đơn và tiền tip. (`scatter plot`)

# %%
sns.scatterplot(x=df['total_bill'], y=df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 7. Tìm hiểu và sử dụng hàm `jointplot` trong seaborn để khảo sát quan hệ giữa hai thuộc tính `total_bill` và `tip`. Theo bạn hai thuộc tính này có tương quan với nhau hay không?

# %%
sns.jointplot(x=df['total_bill'], y=df['tip'])

print("Hai thuoc tinh co lien quan voi nhau")
# Out:
# Hai thuoc tinh co lien quan voi nhau

# %% [markdown]
# ### 8. Tìm hiểu và sử dụng hàm `pairplot` trong seaborn để trực quan bộ dữ liệu. Theo bạn, trong bộ dữ liệu có những thuộc tính nào liên quan với nhau không?

# %%
sns.pairplot(df)

# %% [markdown]
# ### 9. Vẽ hai đồ thị histogram cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
total_bill_by_lunch = df[df['time'] == 'Lunch']['total_bill']
total_bill_by_dinner = df[df['time'] == 'Dinner']['total_bill']

plt.subplot(1, 2, 1)
sns.histplot(total_bill_by_lunch, bins=100)
plt.title("Lunch")


plt.subplot(1, 2, 2)
sns.histplot(total_bill_by_dinner, bins=100)
plt.title("Dinner")

plt.show()

# %% [markdown]
# ### 10. Vẽ hai đồ thị boxplot cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
total_bill_by_lunch = df[df['time'] == 'Lunch']['total_bill']
total_bill_by_dinner = df[df['time'] == 'Dinner']['total_bill']

plt.subplot(1, 2, 1)
sns.boxplot(x=total_bill_by_lunch)
plt.title("Lunch")

plt.subplot(1, 2, 2)
sns.boxplot(x=total_bill_by_dinner)
plt.title("Dinner")

plt.show()

# %% [markdown]
# ---
